# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
df = pd.read_csv('https://raw.githubusercontent.com/heliphix/btc_data/master/btc_data.csv')
df
# Out:
#             Date   priceUSD  transactions        size  sentbyaddress  \
# 0     2010/07/17     0.0495           235     649.653            390
# 1     2010/07/18     0.0726           248     765.285            424
# 2     2010/07/19     0.0859           354     756.040            553
# 3     2010/07/20     0.0783           413     984.707            632
# 4     2010/07/21     0.0767           256     542.483            440
# ...          ...        ...           ...         ...            ...
# 3483  2020/01/29  9349.0000        340402  706867.000         433958
# 3484  2020/01/30  9394.0000        332402  704883.000         416980
# 3485  2020/01/31  9366.0000        334290  770486.000         398021
# 3486  2020/02/01  9393.0000        303573  650769.000         338567
# 3487  2020/02/02  9398.0000        290736  684127.000         257655
#
#         difficulty      hashrate  mining_profitability  sentinusdUSD  \
# ...

# %% [markdown]
# ## skip feature selection

# %%
# print(df.columns.tolist()) #check all columns names
# get only the predictive feature calculated (feature selection) by research, don't use Data appearantly not needed?
df = df[['difficulty30rsi','difficulty90var','fee_to_reward90rsiUSD','hashrate30var','median_transaction_fee7rocUSD','mining_profitability','price30smaUSD','price3wmaUSD','price7wmaUSD','sentinusd90emaUSD','size90trx','top100cap','transactionvalueUSD','priceUSD']]
df
# Out:
#       difficulty30rsi  difficulty90var  fee_to_reward90rsiUSD  hashrate30var  \
# 0              99.914     3.594990e+02                  0.000   3.929777e+17
# 1              99.914     6.493910e+02                  0.000   4.286195e+17
# 2              99.914     9.318310e+02                  0.000   4.596913e+17
# 3              99.914     1.207000e+03                  0.000   4.924702e+17
# 4              99.914     1.476000e+03                  0.000   5.264152e+17
# ...               ...              ...                    ...            ...
# 3483           95.807     5.572319e+23                 48.955   4.897415e+37
# 3484           95.807     6.031298e+23                 48.935   5.375305e+37
# 3485           95.807     6.482502e+23                 49.297   5.198420e+37
# 3486           95.807     6.925930e+23                 48.831   5.466771e+37
# 3487           95.807     7.361582e+23                 48.864   5.485185e+37
#
# ...

# %%
# df = df[['Date','priceUSD']]
print("Top 5")
print(df.head(5))
print("Bottom 5")
print(df.tail(5))
print(df.shape)
# Out:
# Top 5
#          Date  priceUSD
# 0  2010/07/17    0.0495
# 1  2010/07/18    0.0726
# 2  2010/07/19    0.0859
# 3  2010/07/20    0.0783
# 4  2010/07/21    0.0767
# Bottom 5
#             Date  priceUSD
# 3483  2020/01/29    9349.0
# 3484  2020/01/30    9394.0
# 3485  2020/01/31    9366.0
# 3486  2020/02/01    9393.0
# 3487  2020/02/02    9398.0
# (3488, 2)

# %%
plt.plot(df['Date'], df['priceUSD'])
plt.figure(num=None, figsize=(16, 12), dpi=80, facecolor='w', edgecolor='k')
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'priceUSD'], dtype='object')

# %%
|
